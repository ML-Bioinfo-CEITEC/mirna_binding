# %% [markdown]
# <a href="https://colab.research.google.com/github.com/ML-Bioinfo-CEITEC/mirna_binding/blob/master/notebook/model_normal_train_lock.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # General Python Modules

# %%
import pandas as pd
import numpy as np
import os
import time
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Common function
#
# set of functions to generate the one hot encoding version of sequences and dot matrix.

# %% [markdown]
# ## convert input nucleotide sequences to arrays
#
# the code below takes as input a table of three columns:
#
# - genomic binding site ( 50nt length);
# - microRNA sequence (20nt length);
# - label: class [ positive or negative ];
#
# it outputs a list of arrays as:
#
# - 2d matrix of binding vs microRNA with 2 channels. first channel is watson-crick score, second channel is relative position of microRNA (or zero if not required);
# - binding site sequence as tensor of shape 50 x 4, where each channel is a nucleotide;
# - microRNA sequence as tensor of shape 20 x 4, where each channel is a nucleotide;
# - labels: numpy array [ 0 or 1, as negatie or positive];

# %%
def one_hot_encoding(df, tensor_dim=(50,20,1), aux=False, log=False):
    """
    fun transform input database to
    one hot encoding array.
    paramenters:
    df=input table as pandas dataframe
    tensor_dim= 2d matrix shape
    aux=create inputs for LSTM
    log=print log
    """

    # reset df indexes (needed for multithreading)
    df.reset_index(inplace=True, drop=True)
    
    # alphabet for watson-crick interactions.
    alphabet = {"AT": 1., "TA": 1., "GC": 1., "CG": 1.} 
    # one hot encoding of nt sequences for conv1d + LSTM input
    nt_pos_voc = {
        "A" : np.array([1.,0.,0.,0.]),
        "T" : np.array([0.,1.,0.,0.]),
        "C" : np.array([0.,0.,1.,0.]),
        "G" : np.array([0.,0.,0.,1.]),
        "N" : np.array([0.25,0.25,0.25,0.25]),
    
    }

    # labels to one hot encoding
    labels = np.where(df.label == 'positive', 1., 0.)
    
    if aux == True: # conv1d + LSTM input
        bind_matrix_l = list()
        mirna_matrix_l = list()
    else: 
        bind_matrix, mirna_matrix = None, None

    # create empty main 2d matrix array
    N = df.shape[0] # number of samples in df
    shape_matrix_2d = (N, *tensor_dim) # 2d matrix shape 
    ohe_matrix_2d = np.zeros(shape_matrix_2d, dtype="float32")

    start = time.time()

    for index, row in df.iterrows():        
        if aux:
            bind_matrix_l.append(
                [nt_pos_voc[letter] for letter in row.binding_sequence.upper()]
                                  )
            mirna_matrix_l.append(
                [nt_pos_voc[letter] for letter in row.mirna_binding_sequence.upper()]
                    )

        for bind_index, bind_nt in enumerate(row.binding_sequence.upper()):
                
            for mirna_index, mirna_nt in enumerate(
                row.mirna_binding_sequence.upper()
            ):

                pair = bind_nt + mirna_nt
                ohe_matrix_2d[index, bind_index, mirna_index, 0] = alphabet.get(pair, 0)
                
        if index % 1000 == 0 and log==True: # write something
            end = time.time()
            print(
                "rows:\t%s" % (index),
                "elapsed (sec):\t%s" % (end - start),
                sep=" | ",
            )

    if aux:
        bind_matrix = np.array(bind_matrix_l)
        mirna_matrix = np.array(mirna_matrix_l)
    if aux:
        return (ohe_matrix_2d, bind_matrix, mirna_matrix, labels)
    else:
        return (ohe_matrix_2d, labels)

# %% [markdown]
# ##  general function to manage files

# %%
import joblib

def save_joblib(object_, filepath):
    joblib.dump(object_, filepath)
    return filepath

def load_joblib(filepath):
    return joblib.load(filepath)

# %% [markdown]
# ## Parallelized conversion of an array/dataframe to 2D matrix
#
# The below function takes as input a Pandas df or numpy array, and split it into  batches for parallelization.
#
# Usage:
#
# `output = multithread(df, one_hot_encoding, aux=False, log=False, n_cores=24)`
# `data = join_cores_results(output, aux=True)`

# %%
def join_cores_results(multithread_output, aux=False):
  """ join the output of different core processes """
  if aux:
    array_2d_matrix = np.concatenate(
        [ process[0] for process in multithread_output ]
        )
    array_bind_seq = np.concatenate(
        [ process[1] for process in multithread_output ]
        )
    array_micro_seq = np.concatenate(
        [ process[2] for process in multithread_output ]
        )
    array_labels = np.concatenate(
        [ process[3] for process in multithread_output ]
        )
    return (array_2d_matrix, array_bind_seq,
            array_micro_seq, array_labels)
  else:
    array_2d_matrix = np.concatenate(
        [ process[0] for process in multithread_output ]
        )
    array_labels = np.concatenate(
        [ process[1] for process in multithread_output ]
        )
    return (array_2d_matrix, array_labels)

# %%
from multiprocessing import Pool
from functools import partial

def multithread(df, func, aux=False, log=False, n_cores=4):
    iterable = np.array_split(df, n_cores)
    pool = Pool(n_cores)
    lock_func = partial(func, aux=aux, log=log)
    df_update = pool.map(lock_func, iterable)
    pool.close()
    pool.join()
    data = join_cores_results(df_update, aux=aux)
    return data

# %% [markdown]
# ## shuffle positive to create negative
#
# The function generates the negative class by creating a connection between each
#
# binding site and all mirna (expect the real one). If argument mirna_dict is
#
# provided as dictionary of mirna sequences, this dictionary will be used to
#
# create the negative class. Otherwise, all unique mirna sequences of the input
#
# df will be used to generate samples for the negative class.

# %%
def negative_class_shuffle(df, mirna_dict=None, neg_ratio=None):
    if not mirna_dict:
        # generate mirna db of unique sequences
        mirnadb = pd.DataFrame(
            df.mirna_binding_sequence.unique(), columns=['mirnaid']
        )
    else:
        mirnadb = pd.DataFrame(mirna_dict)
        mirnadb.columns = ['mirnaid']
    # add mirna db to each row of df
    connections = mirnadb.assign(key=1).merge(
          df.assign(key=1), on='key'
          ).drop(['key', 'label'],axis=1)
    # find index of positive connection
    positive_samples_mask = (connections.mirnaid == 
                             connections.mirna_binding_sequence)
    # drop positive connection to create negative samples
    negative_df = connections[~positive_samples_mask].copy().drop(
      ['mirna_binding_sequence'], axis=1
      ).reset_index(drop=True)
    # rename cols
    negative_df.columns = ['mirna_binding_sequence', 'binding_sequence']
    # add negative labels
    negative_df['label'] = 'negative'
    if neg_ratio == None:
        return negative_df
    else:
        neg_samples = int(df.shape[0] * neg_ratio)
        return negative_df.sample(n = neg_samples)

# %% [markdown]
# ## Create Hand-Picked Mini-Batches
#
# Create minibatches keeping the original positive-negative ratio. It returns a list of minibatches (pos + neg together).

# %%
def make_minibatches(pos_samples, neg_samples, split_batch ):
    batches_list = []
    ## split subset_pos.class into minibatches
    ### see numpy doc for more details:
    # https://docs.scipy.org/doc/numpy/reference/generated/numpy.split.html
    batch_pos = np.array_split(pos_samples, split_batch)
    ## split subset_neg into minibatches
    ## of size == SPLIT_BATCH
    batch_neg = np.array_split(neg_samples, split_batch)
    ## zip together pos and neg subsets to create minibatches
    for mini_index, minibatch_pairs in enumerate(zip(batch_pos, batch_neg)):
        print('### minibatch pair id is:', mini_index,
              'pos shape is:', minibatch_pairs[0].shape[0],
              'neg_shape_is:', minibatch_pairs[1].shape[0],
              sep='\t'
              )

        batch_train = pd.concat(minibatch_pairs)
        # append each minibatch to minibatch list
        batches_list.append(batch_train)
    return batches_list

# %% [markdown]
# ## Model

# %% [markdown]
# ### Model Architecture

# %%
from tensorflow import keras as keras 
from tensorflow.keras.layers import BatchNormalization, LeakyReLU, Input, Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras import Model
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping

# %%
def make_arch_00b():
    main_input = Input(shape=(50,20,1), dtype='float32', name='main_input')

    x = Conv2D(
        filters=32,
        kernel_size=(3, 3),
        padding="same",
        data_format="channels_last",
        name="conv_1")(main_input)    
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2), name='Max_1')(x)
    x = Dropout(rate = 0.25)(x)


    x = Conv2D(
        filters=64,
        kernel_size=(3, 3),
        padding="same",
        data_format="channels_last",
        name="conv_2")(x)
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2), name='Max_2')(x)
    x = Dropout(rate = 0.25)(x)

    x = Conv2D(
        filters=128,
        kernel_size=(3, 3),
        padding="same",
        data_format="channels_last",
        name="conv_3")(x)
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = MaxPooling2D(pool_size=(2, 2), name='Max_3')(x)
    x = Dropout(rate = 0.25)(x)


    conv_flat = Flatten(name='2d_matrix')(x)

    x = Dense(128)(conv_flat)
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = Dropout(rate = 0.25)(x)

    x = Dense(64)(x)
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = Dropout(rate = 0.25)(x)

    x = Dense(32)(x)
    x = LeakyReLU()(x)
    x = BatchNormalization()(x)
    x = Dropout(rate = 0.25)(x)

    main_output = Dense(1, activation='sigmoid', name='main_output')(x)

    model = Model(inputs=[main_input], outputs=[main_output], name='arch_00b')
    
    return model

# %% [markdown]
# ### Train Function

# %%
def train(
    model, minibatch,
    sample_weight=None,
    class_weight=None,
    reset_metrics=True,
    aux=False
    ):
    if not aux:
        ## assign samples and labels
        X_ohe, y_ohe = minibatch
    else:
        raise NotImplementedError
    
    model_loss = model.train_on_batch(
        { "main_input" : X_ohe},
        { "main_output" : y_ohe},
        sample_weight=sample_weight,
        class_weight=class_weight,
        reset_metrics=reset_metrics
    )
    return model, model_loss

# %% [markdown]
# # Run Pipeline

# %% [markdown]
# ## Create Dataset

# %%
DATASET_NAME = "enc09.joblib"
DATASET_PATH = "/home/grioni_andrea/media/disk_1/grioni_andrea/data/sets/train/enc09.joblib"
POSITIVE_SAMPLES = 250000
NEG_RATIO = 10
RANDOM_STATE = 1789
MINIBATCH_SPLIT = 500
AUX = False
CORES = 8
EXPORT = False # set True if you want to save the train dataset
WORK_DIR = "/home/grioni_andrea/media/disk_1/grioni_andrea/paper/train/normal/"
STRATEGY = "normal"
MODEL_ID = "model_02"

# %% [markdown]
# ### Load Dataset

# %%
df = load_joblib(DATASET_PATH)
dataframe = df[['binding_sequence', 'mirna_binding_sequence', 'label']].copy()
print('dataframe shape is:', dataframe.shape)
# Out:
# dataframe shape is: (255588, 3)

# %% [markdown]
# ### Select Samples for Positive Class

# %%
positive_samples = dataframe.sample(n = POSITIVE_SAMPLES, random_state=RANDOM_STATE)
print('positive samples are:', positive_samples.shape)
print('unique mirna sequences number is:', positive_samples.mirna_binding_sequence.nunique())
# Out:
# positive samples are: (250000, 3)
# unique mirna sequences number is: 406

# %% [markdown]
# ### Generate Samples for Negative Class

# %%
negative_samples = negative_class_shuffle(positive_samples, neg_ratio = NEG_RATIO)
print('negative samples are:', negative_samples.shape)
# Out:
# negative samples are: (2500000, 3)

# %% [markdown]
# ## EXPORT: Convert Negative and Positive Class to one hot encodig
#
# These section can be used to export 2d matrix for both positive and negative classes to file for future usage. If you do not need it, you can skip it and go to "Create hand-made mini-batches" section.

# %%
if EXPORT:
    negative_ohe = multithread(negative_samples, one_hot_encoding, aux=AUX, log=False, n_cores=CORES)
    positive_ohe = multithread(positive_samples, one_hot_encoding, aux=AUX, log=False, n_cores=CORES)

# %% [markdown]
# ### export to files

# %%
if EXPORT:
    output_pos_dir = "./positive_set.joblib"
    output_neg_dir = "./negative_set.joblib"

    save_joblib(positive_ohe, output_pos_dir)
    save_joblib(negative_ohe, output_neg_dir)

# %% [markdown]
# ## Create hand-made mini-batches

# %%
minibatches_list = make_minibatches(positive_samples, negative_samples, MINIBATCH_SPLIT )
# Out:
# ### minibatch pair id is:	0	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	1	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	2	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	3	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	4	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	5	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	6	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	7	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	8	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	9	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	10	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	11	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	12	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	13	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	14	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	15	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	16	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	17	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	18	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	19	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	20	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	21	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	22	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	23	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	24	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	25	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	26	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	27	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	28	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	29	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	30	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	31	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	32	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	33	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	34	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	35	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	36	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	37	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	38	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	39	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	40	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	41	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	42	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	43	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	44	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	45	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	46	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	47	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	48	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	49	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	50	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	51	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	52	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	53	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	54	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	55	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	56	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	57	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	58	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	59	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	60	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	61	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	62	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	63	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	64	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	65	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	66	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	67	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	68	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	69	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	70	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	71	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	72	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	73	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	74	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	75	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	76	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	77	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	78	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	79	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	80	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	81	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	82	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	83	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	84	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	85	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	86	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	87	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	88	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	89	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	90	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	91	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	92	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	93	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	94	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	95	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	96	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	97	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	98	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	99	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	100	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	101	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	102	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	103	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	104	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	105	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	106	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	107	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	108	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	109	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	110	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	111	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	112	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	113	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	114	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	115	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	116	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	117	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	118	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	119	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	120	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	121	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	122	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	123	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	124	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	125	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	126	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	127	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	128	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	129	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	130	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	131	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	132	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	133	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	134	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	135	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	136	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	137	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	138	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	139	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	140	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	141	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	142	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	143	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	144	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	145	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	146	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	147	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	148	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	149	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	150	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	151	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	152	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	153	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	154	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	155	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	156	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	157	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	158	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	159	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	160	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	161	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	162	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	163	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	164	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	165	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	166	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	167	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	168	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	169	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	170	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	171	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	172	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	173	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	174	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	175	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	176	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	177	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	178	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	179	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	180	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	181	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	182	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	183	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	184	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	185	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	186	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	187	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	188	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	189	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	190	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	191	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	192	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	193	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	194	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	195	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	196	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	197	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	198	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	199	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	200	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	201	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	202	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	203	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	204	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	205	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	206	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	207	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	208	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	209	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	210	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	211	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	212	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	213	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	214	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	215	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	216	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	217	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	218	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	219	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	220	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	221	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	222	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	223	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	224	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	225	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	226	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	227	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	228	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	229	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	230	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	231	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	232	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	233	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	234	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	235	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	236	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	237	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	238	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	239	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	240	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	241	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	242	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	243	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	244	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	245	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	246	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	247	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	248	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	249	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	250	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	251	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	252	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	253	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	254	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	255	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	256	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	257	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	258	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	259	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	260	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	261	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	262	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	263	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	264	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	265	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	266	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	267	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	268	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	269	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	270	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	271	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	272	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	273	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	274	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	275	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	276	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	277	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	278	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	279	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	280	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	281	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	282	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	283	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	284	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	285	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	286	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	287	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	288	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	289	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	290	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	291	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	292	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	293	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	294	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	295	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	296	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	297	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	298	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	299	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	300	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	301	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	302	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	303	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	304	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	305	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	306	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	307	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	308	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	309	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	310	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	311	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	312	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	313	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	314	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	315	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	316	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	317	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	318	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	319	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	320	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	321	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	322	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	323	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	324	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	325	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	326	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	327	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	328	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	329	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	330	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	331	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	332	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	333	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	334	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	335	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	336	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	337	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	338	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	339	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	340	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	341	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	342	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	343	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	344	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	345	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	346	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	347	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	348	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	349	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	350	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	351	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	352	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	353	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	354	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	355	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	356	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	357	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	358	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	359	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	360	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	361	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	362	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	363	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	364	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	365	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	366	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	367	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	368	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	369	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	370	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	371	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	372	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	373	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	374	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	375	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	376	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	377	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	378	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	379	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	380	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	381	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	382	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	383	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	384	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	385	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	386	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	387	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	388	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	389	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	390	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	391	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	392	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	393	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	394	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	395	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	396	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	397	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	398	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	399	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	400	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	401	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	402	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	403	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	404	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	405	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	406	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	407	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	408	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	409	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	410	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	411	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	412	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	413	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	414	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	415	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	416	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	417	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	418	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	419	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	420	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	421	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	422	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	423	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	424	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	425	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	426	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	427	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	428	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	429	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	430	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	431	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	432	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	433	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	434	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	435	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	436	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	437	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	438	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	439	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	440	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	441	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	442	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	443	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	444	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	445	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	446	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	447	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	448	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	449	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	450	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	451	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	452	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	453	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	454	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	455	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	456	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	457	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	458	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	459	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	460	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	461	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	462	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	463	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	464	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	465	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	466	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	467	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	468	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	469	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	470	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	471	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	472	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	473	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	474	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	475	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	476	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	477	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	478	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	479	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	480	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	481	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	482	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	483	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	484	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	485	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	486	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	487	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	488	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	489	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	490	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	491	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	492	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	493	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	494	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	495	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	496	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	497	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	498	pos shape is:	500	neg_shape_is:	5000
# ### minibatch pair id is:	499	pos shape is:	500	neg_shape_is:	5000

# %% [markdown]
# ## Create Model

# %%
from tensorflow.keras import backend as K
K.clear_session()

model = make_arch_00b()
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    )

# %% [markdown]
# ## Train as Generator
#
# This code will fit each mini-batch to the model. The conversion from mini-batch dataframe to one hot encoding happen on-the-fly to save memory resources.

# %% [markdown]
# ### Normal Training

# %%
# keep the last minibatch as validation set
validation_batch, minibatches_train = minibatches_list[-1], minibatches_list[ : -1]
val_ohe = multithread(validation_batch, one_hot_encoding, aux=AUX, log=False, n_cores=CORES)
# set paramenters
EPOCHS = 10
TRAIN_LOSSES = np.zeros( (EPOCHS, 1) )
VAL_LOSSES = np.zeros((EPOCHS, 1))
LOG = list()
# set callbacks

cycle = 0
for epoch in range(EPOCHS):
    epoch_train_losses = np.zeros( (len(minibatches_train), 1) )
    epoch_val_losses = np.zeros( (len(minibatches_train), 1) )

    print(f'#\tSTART EPOCH:\t{epoch}')
    for mini_index, minibatch in enumerate(minibatches_train):
        sample_size = minibatch.shape[0]
        data_ohe = multithread(minibatch, one_hot_encoding, aux=AUX, log=False, n_cores=CORES)
        model, model_loss = train(model, data_ohe, reset_metrics=False)
        epoch_train_losses[mini_index] = model_loss
        
        val_los = model.test_on_batch(
            { "main_input" : val_ohe[0]},
            { "main_output" : val_ohe[1]}
            )
        epoch_val_losses[mini_index] = val_los
        print(f'\tminibatch:{mini_index}|\ttrain on samples:{sample_size}|\t' + 
              f'train loss:{model_loss}|\tval loss:{val_los}', '\n')
        
        LOG.append([DATASET_NAME, STRATEGY, EPOCHS, cycle, POSITIVE_SAMPLES, NEG_RATIO,
                    epoch, mini_index, sample_size, model_loss, val_los])
        cycle += 1
    model.save( f'{WORK_DIR}/{epoch}.{MODEL_ID}.h5')
    TRAIN_LOSSES[epoch] = epoch_train_losses.sum() / (1.0 * len(epoch_train_losses))
    VAL_LOSSES[epoch] = epoch_val_losses.sum() / (1.0 * len(epoch_val_losses))

final_train_loss = TRAIN_LOSSES.sum() / (1.0 * len(TRAIN_LOSSES))
final_val_loss = VAL_LOSSES.sum() / (1.0 * len(VAL_LOSSES))

print(final_train_loss, final_val_loss)

# save results
col_names = ("dataset,strategy,total_epochs,cycle,positive_samples," + 
             "neg_ratio,epoch,mini_index,tot_samples,train_loss,val_loss").split(',')
log_df = pd.DataFrame(LOG, columns=col_names)    
log_df.to_csv(f'{WORK_DIR}/train.{MODEL_ID}.log.csv', index=False, sep=',')

model.save( f'{WORK_DIR}/{MODEL_ID}.h5')
# Out:
# #	START EPOCH:	0
# 	minibatch:0|	train on samples:5500|	train loss:1.0105211734771729|	val loss:0.7426842451095581
#
# 	minibatch:1|	train on samples:5500|	train loss:0.9618327617645264|	val loss:0.7358652949333191
#
# 	minibatch:2|	train on samples:5500|	train loss:0.9272983074188232|	val loss:0.7274988293647766
#
# 	minibatch:3|	train on samples:5500|	train loss:0.9096933603286743|	val loss:0.723459005355835
#
# 	minibatch:4|	train on samples:5500|	train loss:0.889648973941803|	val loss:0.721407413482666
#
# 	minibatch:5|	train on samples:5500|	train loss:0.8524019718170166|	val loss:0.7157011032104492
#
# 	minibatch:6|	train on samples:5500|	train loss:0.84372478723526|	val loss:0.7119900584220886
#
# 	minibatch:7|	train on samples:5500|	train loss:0.8150548934936523|	val loss:0.7073625922203064
#
# 	minibatch:8|	train on samples:5500|	train loss:0.8319933414459229|	val loss:0.7012004852294922
#
# 	minibatch:9|	train on samples:5500|	train loss:0.8046963810920715|	val loss:0.6944630146026611
#
# 	minibatch:10|	train on samples:5500|	train loss:0.8040972948074341|	val loss:0.6856778264045715
#
# 	minibatch:11|	train on samples:5500|	train loss:0.7957780361175537|	val loss:0.6776250600814819
#
# 	minibatch:12|	train on samples:5500|	train loss:0.7778347134590149|	val loss:0.6675449013710022
#
# 	minibatch:13|	train on samples:5500|	train loss:0.7760744690895081|	val loss:0.6568427085876465
#
# 	minibatch:14|	train on samples:5500|	train loss:0.751186192035675|	val loss:0.6463587284088135
#
# 	minibatch:15|	train on samples:5500|	train loss:0.7611832618713379|	val loss:0.6356562972068787
#
# 	minibatch:16|	train on samples:5500|	train loss:0.7486481070518494|	val loss:0.6255593299865723
#
# 	minibatch:17|	train on samples:5500|	train loss:0.7546820044517517|	val loss:0.6174018383026123
#
# 	minibatch:18|	train on samples:5500|	train loss:0.7374644875526428|	val loss:0.6101669669151306
#
# 	minibatch:19|	train on samples:5500|	train loss:0.7346781492233276|	val loss:0.603301465511322
#
# 	minibatch:20|	train on samples:5500|	train loss:0.7270283102989197|	val loss:0.5966620445251465
#
# 	minibatch:21|	train on samples:5500|	train loss:0.7288839817047119|	val loss:0.5902630686759949
#
# 	minibatch:22|	train on samples:5500|	train loss:0.7156581878662109|	val loss:0.5841156840324402
